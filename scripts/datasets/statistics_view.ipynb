# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
valid_stat_dict = {
    # "total": 7868,
    "Atelectasis": 690,
    "Cardiomegaly": 569,
    "Consolidation": 80,
    "Edema": 223,
    "Enlarged Cardiomediastinum": 62,
    "Fracture": 76,
    "Lung Lesion": 150,
    "Lung Opacity": 896,
    # "No Finding": 4684,
    "Pleural Effusion": 891,
    "Pleural Other": 55,
    "Pneumonia": 367,
    "Pneumothorax": 131,
    "Support Devices": 329,
}

# %%
train_stat_dict = {
#  'total': 71075,
 'Atelectasis': 5947,
 'Cardiomegaly': 4598,
 'Consolidation': 975,
 'Edema': 2058,
 'Enlarged Cardiomediastinum': 568,
 'Fracture': 781,
 'Lung Lesion': 1565,
 'Lung Opacity': 8021,
#  'No Finding': 43251,
 'Pleural Effusion': 6684,
 'Pleural Other': 440,
 'Pneumonia': 3562,
 'Pneumothorax': 1135,
 'Support Devices': 2855}

# %%
fig, ax = plt.subplots(figsize=(18, 5))
x = []
y = []
for k, v in valid_stat_dict.items():
    x.append(k)
    y.append(v)
ax.bar(
    x,
    y,
)

for a, b in zip(x, y):
    plt.text(
        a,
        b,
        b,
        ha="center",
        va="bottom",
    )
ax.set_title("valid disease count")
plt.xticks(fontsize=8, rotation=45)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18, 5))
x = []
y = []
for k, v in train_stat_dict.items():
    x.append(k)
    y.append(v)
ax.bar(
    x,
    y,
)
for a, b in zip(x, y):
    plt.text(
        a,
        b,
        b,
        ha="center",
        va="bottom",
    )
ax.set_title("valid disease count")
plt.xticks(fontsize=8, rotation=45)
plt.show()

# %%
multi_stat_dict = {
    # "total": 1315,
    "Atelectasis-Cardiomegaly": 86,
    "Atelectasis-Fracture": 10,
    "Atelectasis-Pleural Effusion": 272,
    "Cardiomegaly-Fracture": 7,
    "Cardiomegaly-Pleural Effusion": 133,
    "Fracture-Pleural Effusion": 2,
    "Atelectasis-Lung Opacity": 196,
    "Pleural Effusion-Support Devices": 67,
    "Lung Lesion-Lung Opacity": 52,
    "Lung Lesion-Pneumonia": 5,
    "Lung Opacity-Pneumonia": 127,
    "Lung Opacity-Pneumothorax": 17,
    "Lung Opacity-Support Devices": 34,
    "Pneumothorax-Support Devices": 38,
    "Cardiomegaly-Lung Opacity": 57,
    "Cardiomegaly-Support Devices": 56,
    "Lung Opacity-Pleural Effusion": 180,
    "Consolidation-Pneumonia": 21,
    "Consolidation-Lung Opacity": 20,
    "Cardiomegaly-Edema": 72,
    "Lung Lesion-Support Devices": 16,
    "Edema-Pleural Effusion": 102,
    "No Finding-Support Devices": 113,
    "Edema-Lung Opacity": 52,
    "Cardiomegaly-Enlarged Cardiomediastinum": 2,
    "Enlarged Cardiomediastinum-Pleural Effusion": 11,
    "Atelectasis-Edema": 29,
    "Atelectasis-Support Devices": 51,
    "Cardiomegaly-Pleural Other": 9,
    "Lung Opacity-Pleural Other": 16,
    "Pleural Effusion-Pneumonia": 52,
    "Atelectasis-Pneumonia": 43,
    "Cardiomegaly-Pneumonia": 19,
    "Cardiomegaly-Consolidation": 5,
    "Consolidation-Pleural Effusion": 23,
    "Pleural Effusion-Pneumothorax": 46,
    "Lung Lesion-Pleural Effusion": 32,
    "Enlarged Cardiomediastinum-Lung Opacity": 14,
    "Enlarged Cardiomediastinum-Pneumonia": 2,
    "Edema-Pneumonia": 14,
    "Fracture-Support Devices": 5,
    "Pleural Effusion-Pleural Other": 13,
    "Atelectasis-Pleural Other": 5,
    "Pleural Other-Pneumonia": 2,
    "Atelectasis-Pneumothorax": 28,
    "Atelectasis-Lung Lesion": 10,
    "Cardiomegaly-Pneumothorax": 6,
    "Edema-Support Devices": 10,
    "Lung Lesion-Pneumothorax": 3,
    "Lung Lesion-Pleural Other": 1,
    "Pleural Other-Support Devices": 1,
    "Enlarged Cardiomediastinum-Pleural Other": 5,
    "Enlarged Cardiomediastinum-Support Devices": 1,
    "Atelectasis-Enlarged Cardiomediastinum": 8,
    "Pneumonia-Pneumothorax": 1,
    "Atelectasis-Consolidation": 13,
    "Consolidation-Support Devices": 3,
    "Edema-Fracture": 1,
    "Consolidation-Edema": 1,
    "Cardiomegaly-Lung Lesion": 3,
    "Edema-Lung Lesion": 2,
    "Consolidation-Lung Lesion": 2,
    "Consolidation-Pneumothorax": 1,
    "Fracture-Lung Opacity": 1,
    "Fracture-Pneumothorax": 2,
    "Enlarged Cardiomediastinum-Fracture": 2,
    "Fracture-Pleural Other": 2,
    "Fracture-Pneumonia": 1,
    "Pleural Other-Pneumothorax": 1,
    "Pneumonia-Support Devices": 2,
    "Enlarged Cardiomediastinum-Lung Lesion": 2,
    "Fracture-Lung Lesion": 1,
}

# %%
sorted_tuple_list = sorted(multi_stat_dict.items(), key=lambda d: d[1], reverse=True)
print(sorted_tuple_list)
# Out:
# [('Atelectasis-Pleural Effusion', 272), ('Atelectasis-Lung Opacity', 196), ('Lung Opacity-Pleural Effusion', 180), ('Cardiomegaly-Pleural Effusion', 133), ('Lung Opacity-Pneumonia', 127), ('No Finding-Support Devices', 113), ('Edema-Pleural Effusion', 102), ('Atelectasis-Cardiomegaly', 86), ('Cardiomegaly-Edema', 72), ('Pleural Effusion-Support Devices', 67), ('Cardiomegaly-Lung Opacity', 57), ('Cardiomegaly-Support Devices', 56), ('Lung Lesion-Lung Opacity', 52), ('Edema-Lung Opacity', 52), ('Pleural Effusion-Pneumonia', 52), ('Atelectasis-Support Devices', 51), ('Pleural Effusion-Pneumothorax', 46), ('Atelectasis-Pneumonia', 43), ('Pneumothorax-Support Devices', 38), ('Lung Opacity-Support Devices', 34), ('Lung Lesion-Pleural Effusion', 32), ('Atelectasis-Edema', 29), ('Atelectasis-Pneumothorax', 28), ('Consolidation-Pleural Effusion', 23), ('Consolidation-Pneumonia', 21), ('Consolidation-Lung Opacity', 20), ('Cardiomegaly-Pneumonia', 19), ('Lung Opacity-Pneumothorax', 17), ('Lung 
# ...
